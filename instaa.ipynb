# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_csv('Instagram_influencers.csv')
data
# Out:
#     Country  Rank        Account                           Title  \
# 0       All     1      cristiano               Cristiano Ronaldo
# 1       All     2    kyliejenner                         Kylie 🤍
# 2       All     3       leomessi                       Leo Messi
# 3       All     4  kendalljenner                         Kendall
# 4       All     5    selenagomez                    Selena Gomez
# ..      ...   ...            ...                             ...
# 995     All   996  senoritasaeva                      Dina Saeva
# 996     All   997    manuelneuer                    Manuel Neuer
# 997     All   998      sahilkhan  India’s Youth & Fitness IC⭕️N®
# 998     All   999    mohanshakti                    Shakti Mohan
# 999     All  1000       eduincaz                       Eduin Caz
#
#                                          Link  \
# 0        https://www.instagram.com/cristiano/
# 1      https://www.instagram.com/kyliejenner/
# ...

# %%
import matplotlib.pyplot as plt

X=data['Account']
Auth_eng=data['Authentic engagement']
Eng_avg=data['Engagement avg']

X_axis=np.arange(len(X))

plt.bar(X_axis - 0.2, Auth_eng, 0.4, label = 'Authentic Average')
plt.bar(X_axis + 0.2, Eng_avg, 0.4, label = 'Engagement Average')
  
plt.xticks(X_axis, X)
plt.xlabel("Influencers")
plt.ylabel("Engagement")
plt.title("Influencers vs Engagement types")
plt.legend()
plt.show()

# %%
data.head()
# Out:
#   Country  Rank        Account              Title  \
# 0     All     1      cristiano  Cristiano Ronaldo
# 1     All     2    kyliejenner            Kylie 🤍
# 2     All     3       leomessi          Leo Messi
# 3     All     4  kendalljenner            Kendall
# 4     All     5    selenagomez       Selena Gomez
#
#                                        Link                   Category  \
# 0      https://www.instagram.com/cristiano/         Sports with a ball
# 1    https://www.instagram.com/kyliejenner/    Fashion|Modeling|Beauty
# 2       https://www.instagram.com/leomessi/  Sports with a ball|Family
# 3  https://www.instagram.com/kendalljenner/           Modeling|Fashion
# 4    https://www.instagram.com/selenagomez/            Music|Lifestyle
#
#    Followers Audience Country  Authentic engagement  Engagement avg  Scraped
# 0  400100000            India               7800000         9500000  50:24.8
# 1  308800000    United States               6200000        10100000  50:24.8
# ...

# %%
data.info
# Out:
# <bound method DataFrame.info of     Country  Rank        Account                           Title  \
# 0       All     1      cristiano               Cristiano Ronaldo
# 1       All     2    kyliejenner                         Kylie 🤍
# 2       All     3       leomessi                       Leo Messi
# 3       All     4  kendalljenner                         Kendall
# 4       All     5    selenagomez                    Selena Gomez
# ..      ...   ...            ...                             ...
# 995     All   996  senoritasaeva                      Dina Saeva
# 996     All   997    manuelneuer                    Manuel Neuer
# 997     All   998      sahilkhan  India’s Youth & Fitness IC⭕️N®
# 998     All   999    mohanshakti                    Shakti Mohan
# 999     All  1000       eduincaz                       Eduin Caz
#
#                                          Link  \
# 0        https://www.instagram.com/cristiano/
# 1      https://www.instagram.com/kyliejenner/
# ...

# %%
data.describe()
# Out:
#               Rank     Followers  Authentic engagement  Engagement avg
# count  1000.000000  1.000000e+03          1.000000e+03    1.000000e+03
# mean    500.500000  2.483610e+07          6.491228e+05    8.653886e+05
# std     288.819436  3.872143e+07          1.098804e+06    1.267515e+06
# min       1.000000  2.800000e+06          0.000000e+00    5.200000e+04
# 25%     250.750000  9.000000e+06          2.091000e+05    3.086000e+05
# 50%     500.500000  1.440000e+07          3.637000e+05    5.239000e+05
# 75%     750.250000  2.565000e+07          6.832500e+05    9.508000e+05
# max    1000.000000  4.696000e+08          1.340000e+07    1.340000e+07

# %%
data['Audience Country'].value_counts()
# Out:
# United States           283
# Brazil                  161
# India                   143
# Indonesia               130
# Mexico                   50
# Spain                    34
# Russia                   30
# Argentina                24
# Iran                     17
# United Kingdom           17
# Turkey                   16
# Italy                    15
# South Korea              13
# Colombia                  9
# Philippines               7
# France                    6
# Egypt                     6
# Germany                   5
# Nigeria                   4
# Thailand                  4
# Iraq                      4
# Morocco                   3
# Japan                     2
# Saudi Arabia              2
# Kazakhstan                2
# Syria                     1
# China                     1
# Algeria                   1
# United Arab Emirates      1
# Poland                    1
# Chile                     1
# Name: Audience Country, dtype: int64

# %%
data.pivot_table(index="Category",values="Followers", aggfunc=['mean', 'sum', 'min', 'max'], sort=False)
# Out:
#                                                mean         sum        min  \
#                                           Followers   Followers  Followers
# Category
# Sports with a ball                     3.225825e+07  3322600000    5400000
# Fashion|Modeling|Beauty                3.088000e+08   308800000  308800000
# Sports with a ball|Family              1.730500e+08   346100000   39800000
# Modeling|Fashion                       6.622500e+07   264900000   11400000
# Music|Lifestyle                        4.848000e+07   484800000    7600000
# ...                                             ...         ...        ...
# Photography|Lifestyle                  7.900000e+06     7900000    7900000
# Modeling|Music                         6.800000e+06     6800000    6800000
# Beauty|Art|Artists|Modeling            1.360000e+07    13600000   13600000
# Humor|Fun|Happiness|Shows|Art|Artists  1.570000e+07    15700000   15700000
# ...

# %%
data['Category'].value_counts().shape
# Out:
# (165,)

# %%
import matplotlib.pyplot as plyt
data['Category'].value_counts().head().plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
mask=data['Audience Country']=='United States'
df_USA=data[mask]
df_USA.head(6)
# Out:
#   Country  Rank        Account                Title  \
# 1     All     2    kyliejenner              Kylie 🤍
# 3     All     4  kendalljenner              Kendall
# 4     All     5    selenagomez         Selena Gomez
# 5     All     6        zendaya              Zendaya
# 6     All     7  kimkardashian  Kim Kardashian West
# 7     All     8        beyonce             Beyoncé
#
#                                        Link                         Category  \
# 1    https://www.instagram.com/kyliejenner/          Fashion|Modeling|Beauty
# 3  https://www.instagram.com/kendalljenner/                 Modeling|Fashion
# 4    https://www.instagram.com/selenagomez/                  Music|Lifestyle
# 5        https://www.instagram.com/zendaya/  Cinema|Actors/actresses|Fashion
# 6  https://www.instagram.com/kimkardashian/                   Fashion|Beauty
# 7        https://www.instagram.com/beyonce/                    Music|Fashion
#
# ...

# %%
topfollowers = df_USA.nlargest(10,'Followers')

topfollowers.pivot_table(index="Category", values="Followers", aggfunc=['sum'], sort=False)
# Out:
#                                                     sum
#                                               Followers
# Category
# Fashion|Modeling|Beauty                       308800000
# Music|Lifestyle                               295800000
# Music                                         294100000
# Fashion|Beauty                                284900000
# Music|Fashion                                 237200000
# Clothing|Outfits|Lifestyle                    219400000
# Modeling|Fashion                              217800000
# Nature  landscapes|Science|Photography        206600000
# Fitness|Gym|Shopping|Retail|Clothing|Outfits  199000000
# Music|Cinema|Actors/actresses                 194900000

# %%
plt.figure(figsize=(12,8))
fig1 = plt.bar(topfollowers.Category, topfollowers.Followers, label='Followers', width=0.8, color='skyblue')
plt.xticks(fontsize = 12, rotation = 90)
plt.ylabel("Followers", fontsize = 16)
plt.xlabel("Category", fontsize = 16)
plt.title("Top 10 Categories by Followers", fontsize = 20)
plt.tight_layout()
# remove scientific notation
plt.ticklabel_format(axis="y", style='plain')

# %%
plt.figure(figsize=(8,5))
plt.hist(df_USA.Followers, color='red', range=(0,60000000))
plt.xlabel('Followers', fontsize = 16)
plt.ylabel('Number of Instagram Accounts', fontsize = 16)
plt.title('Histogram: Follower Counts of Top Instagram Accounts in the US', fontsize = 20)
plt.tight_layout()
# remove scientific notation
plt.ticklabel_format(style='plain')
